# %% [markdown]
# # Demo Image Augmentation

# %%
# %matplotlib inline
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import OneHotEncoder
from sklearn import preprocessing
import math

from skimage.io import imread, imshow
from skimage import data, color, io, filters, morphology,transform, exposure, feature, util
from scipy import ndimage
import pickle

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing import image

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# %%
# Inladen van de datasets

training_data = unpickle('/Users/pascal-maker/Desktop/deeplearning/Session_02_Convolutional_Neural_Networks_Demos/cifar-10/data_batch_1')
test_data = unpickle('/Users/pascal-maker/Desktop/deeplearning/Session_02_Convolutional_Neural_Networks_Demos/cifar-10/test_batch')


X_train = training_data.get(b'data')
train_labels = training_data.get(b'labels')
X_test = test_data.get(b'data')
test_labels = test_data.get(b'labels')

# Reshape into Tensorflow format (number of images, width, height, color channels)
X_train = X_train.reshape((len(X_train),3,32,32)).transpose(0,2,3,1)
X_test  = X_test.reshape((len(X_test),3,32,32)).transpose(0,2,3,1)

print(X_train.shape)
print(X_test.shape)
# Out:
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
# Toon afbeelding

imshow(X_train[1])

# %%
# Image normalization

# Normalisatie
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# one-hot encoding van de target labels

y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)

print(y_train.shape)
# Out:
# (10000, 10)

# %%
# Neural network parameters
#-----------------------------------------------
#-----------------------------------------------
batch_size = 64 # 
epochs = 100 # 
#-----------------------------------------------
#-----------------------------------------------
num_classes = 10
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols,3)

# Model
model = Sequential()
#-----------------------------------------------
#-----------------------------------------------
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=input_shape)) 
#-----------------------------------------------
#-----------------------------------------------
model.add(MaxPooling2D(pool_size=(2, 2)))
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(0.1)) # Value between 0 and 1 
#-----------------------------------------------
model.add(Conv2D(32, (3, 3), activation='relu')) 
#-----------------------------------------------
#-----------------------------------------------
model.add(MaxPooling2D(pool_size=(2, 2)))
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(0.1)) # Value between 0 and 1 
#-----------------------------------------------
#-----------------------------------------------
model.add(Flatten()) 
model.add(Dense(50, activation='relu')) 
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(0.1)) # Value between 0 and 1 
#-----------------------------------------------
#-----------------------------------------------
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# Trainen van het CNN
history = model.fit(X_train, y_train,batch_size=batch_size, epochs=epochs, validation_data = (X_test,y_test), verbose=1)
# Out:
# Epoch 1/100
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.1656 - loss: 2.2069 - val_accuracy: 0.3395 - val_loss: 1.8291
# Epoch 2/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.3461 - loss: 1.7915 - val_accuracy: 0.4316 - val_loss: 1.5760
# Epoch 3/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.4129 - loss: 1.6013 - val_accuracy: 0.4753 - val_loss: 1.4578
# Epoch 4/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.4567 - loss: 1.4709 - val_accuracy: 0.4981 - val_loss: 1.4018
# Epoch 5/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.4890 - loss: 1.4034 - val_accuracy: 0.5197 - val_loss: 1.3608
# Epoch 6/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.5238 - loss: 1.3346 - val_accuracy: 0.5368 - val_loss: 1.2995
# Epoch 7/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.5553 - loss: 1.2608 - val_accuracy: 0.5353 - val_loss: 1.3106
# Epoch 8/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5593 - loss: 1.2420 - val_accuracy: 0.5563 - val_loss: 1.2503
# Epoch 9/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5779 - loss: 1.1833 - val_accuracy: 0.5560 - val_loss: 1.2591
# Epoch 10/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.5881 - loss: 1.1379 - val_accuracy: 0.5681 - val_loss: 1.2139
# Epoch 11/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6093 - loss: 1.0979 - val_accuracy: 0.5663 - val_loss: 1.2166
# Epoch 12/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6091 - loss: 1.0912 - val_accuracy: 0.5765 - val_loss: 1.2005
# Epoch 13/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6154 - loss: 1.0621 - val_accuracy: 0.5756 - val_loss: 1.2037
# Epoch 14/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6384 - loss: 1.0130 - val_accuracy: 0.5854 - val_loss: 1.1774
# Epoch 15/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6453 - loss: 0.9939 - val_accuracy: 0.5904 - val_loss: 1.1692
# Epoch 16/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.6507 - loss: 0.9873 - val_accuracy: 0.5964 - val_loss: 1.1647
# Epoch 17/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6740 - loss: 0.9370 - val_accuracy: 0.5742 - val_loss: 1.2046
# Epoch 18/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.6630 - loss: 0.9542 - val_accuracy: 0.5735 - val_loss: 1.2137
# Epoch 19/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6810 - loss: 0.8957 - val_accuracy: 0.5920 - val_loss: 1.1859
# Epoch 20/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.6867 - loss: 0.8897 - val_accuracy: 0.6006 - val_loss: 1.1751
# Epoch 21/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.6901 - loss: 0.8676 - val_accuracy: 0.5855 - val_loss: 1.2302
# Epoch 22/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7004 - loss: 0.8564 - val_accuracy: 0.5852 - val_loss: 1.1959
# Epoch 23/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6941 - loss: 0.8483 - val_accuracy: 0.5880 - val_loss: 1.2055
# Epoch 24/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7097 - loss: 0.8234 - val_accuracy: 0.6018 - val_loss: 1.1801
# Epoch 25/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7228 - loss: 0.7920 - val_accuracy: 0.5916 - val_loss: 1.1982
# Epoch 26/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7159 - loss: 0.7880 - val_accuracy: 0.6001 - val_loss: 1.2071
# Epoch 27/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7289 - loss: 0.7543 - val_accuracy: 0.6028 - val_loss: 1.1917
# Epoch 28/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7282 - loss: 0.7582 - val_accuracy: 0.5986 - val_loss: 1.2120
# Epoch 29/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7407 - loss: 0.7305 - val_accuracy: 0.6081 - val_loss: 1.1945
# Epoch 30/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7473 - loss: 0.6962 - val_accuracy: 0.5908 - val_loss: 1.2322
# Epoch 31/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7515 - loss: 0.6948 - val_accuracy: 0.5987 - val_loss: 1.2302
# Epoch 32/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7518 - loss: 0.6888 - val_accuracy: 0.5985 - val_loss: 1.2322
# Epoch 33/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7604 - loss: 0.6756 - val_accuracy: 0.5978 - val_loss: 1.2185
# Epoch 34/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7637 - loss: 0.6443 - val_accuracy: 0.6027 - val_loss: 1.2402
# Epoch 35/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7743 - loss: 0.6250 - val_accuracy: 0.5964 - val_loss: 1.3084
# Epoch 36/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7671 - loss: 0.6481 - val_accuracy: 0.5996 - val_loss: 1.2638
# Epoch 37/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7728 - loss: 0.6151 - val_accuracy: 0.6002 - val_loss: 1.3046
# Epoch 38/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7902 - loss: 0.5912 - val_accuracy: 0.5952 - val_loss: 1.2950
# Epoch 39/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7810 - loss: 0.5990 - val_accuracy: 0.5917 - val_loss: 1.2879
# Epoch 40/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7774 - loss: 0.5958 - val_accuracy: 0.6071 - val_loss: 1.2851
# Epoch 41/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7872 - loss: 0.5940 - val_accuracy: 0.6088 - val_loss: 1.3031
# Epoch 42/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7993 - loss: 0.5586 - val_accuracy: 0.5919 - val_loss: 1.3094
# Epoch 43/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7962 - loss: 0.5518 - val_accuracy: 0.5963 - val_loss: 1.3419
# Epoch 44/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8037 - loss: 0.5471 - val_accuracy: 0.5867 - val_loss: 1.3701
# Epoch 45/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8042 - loss: 0.5437 - val_accuracy: 0.6007 - val_loss: 1.3526
# Epoch 46/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8090 - loss: 0.5318 - val_accuracy: 0.5979 - val_loss: 1.3521
# Epoch 47/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8130 - loss: 0.5361 - val_accuracy: 0.5974 - val_loss: 1.3379
# Epoch 48/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8154 - loss: 0.5227 - val_accuracy: 0.6013 - val_loss: 1.3765
# Epoch 49/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8122 - loss: 0.5267 - val_accuracy: 0.5983 - val_loss: 1.3886
# Epoch 50/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8195 - loss: 0.5001 - val_accuracy: 0.5967 - val_loss: 1.4100
# Epoch 51/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8244 - loss: 0.4869 - val_accuracy: 0.5901 - val_loss: 1.4333
# Epoch 52/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8246 - loss: 0.4760 - val_accuracy: 0.5971 - val_loss: 1.4385
# Epoch 53/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8291 - loss: 0.4756 - val_accuracy: 0.5910 - val_loss: 1.4867
# Epoch 54/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8240 - loss: 0.4747 - val_accuracy: 0.5968 - val_loss: 1.4286
# Epoch 55/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8187 - loss: 0.4953 - val_accuracy: 0.5971 - val_loss: 1.4452
# Epoch 56/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8414 - loss: 0.4493 - val_accuracy: 0.6009 - val_loss: 1.4780
# Epoch 57/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8267 - loss: 0.4745 - val_accuracy: 0.5983 - val_loss: 1.4667
# Epoch 58/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8314 - loss: 0.4528 - val_accuracy: 0.5954 - val_loss: 1.4546
# Epoch 59/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8460 - loss: 0.4249 - val_accuracy: 0.5921 - val_loss: 1.4944
# Epoch 60/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8337 - loss: 0.4711 - val_accuracy: 0.5904 - val_loss: 1.5304
# Epoch 61/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8461 - loss: 0.4302 - val_accuracy: 0.5953 - val_loss: 1.4646
# Epoch 62/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8423 - loss: 0.4366 - val_accuracy: 0.6007 - val_loss: 1.5759
# Epoch 63/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8435 - loss: 0.4231 - val_accuracy: 0.5972 - val_loss: 1.5388
# Epoch 64/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8412 - loss: 0.4291 - val_accuracy: 0.6007 - val_loss: 1.5857
# Epoch 65/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8497 - loss: 0.4167 - val_accuracy: 0.5934 - val_loss: 1.5382
# Epoch 66/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8523 - loss: 0.4096 - val_accuracy: 0.5906 - val_loss: 1.5615
# Epoch 67/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8568 - loss: 0.3992 - val_accuracy: 0.5951 - val_loss: 1.5555
# Epoch 68/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8586 - loss: 0.4025 - val_accuracy: 0.5931 - val_loss: 1.6557
# Epoch 69/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8648 - loss: 0.3833 - val_accuracy: 0.5855 - val_loss: 1.6145
# Epoch 70/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8541 - loss: 0.4048 - val_accuracy: 0.5960 - val_loss: 1.5627
# Epoch 71/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8583 - loss: 0.3792 - val_accuracy: 0.5950 - val_loss: 1.6111
# Epoch 72/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8667 - loss: 0.3703 - val_accuracy: 0.5920 - val_loss: 1.6155
# Epoch 73/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8558 - loss: 0.3919 - val_accuracy: 0.5937 - val_loss: 1.6416
# Epoch 74/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8686 - loss: 0.3628 - val_accuracy: 0.5913 - val_loss: 1.6904
# Epoch 75/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8621 - loss: 0.3815 - val_accuracy: 0.5899 - val_loss: 1.6497
# Epoch 76/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8627 - loss: 0.3739 - val_accuracy: 0.6006 - val_loss: 1.6546
# Epoch 77/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8732 - loss: 0.3566 - val_accuracy: 0.5930 - val_loss: 1.6586
# Epoch 78/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8646 - loss: 0.3699 - val_accuracy: 0.5872 - val_loss: 1.7126
# Epoch 79/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8701 - loss: 0.3793 - val_accuracy: 0.5941 - val_loss: 1.6536
# Epoch 80/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8767 - loss: 0.3368 - val_accuracy: 0.5959 - val_loss: 1.7013
# Epoch 81/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8817 - loss: 0.3340 - val_accuracy: 0.5914 - val_loss: 1.7129
# Epoch 82/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8766 - loss: 0.3509 - val_accuracy: 0.5891 - val_loss: 1.6809
# Epoch 83/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8700 - loss: 0.3554 - val_accuracy: 0.5954 - val_loss: 1.7416
# Epoch 84/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8773 - loss: 0.3483 - val_accuracy: 0.5923 - val_loss: 1.7316
# Epoch 85/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8755 - loss: 0.3420 - val_accuracy: 0.5942 - val_loss: 1.7489
# Epoch 86/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8852 - loss: 0.3230 - val_accuracy: 0.5876 - val_loss: 1.7672
# Epoch 87/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8700 - loss: 0.3494 - val_accuracy: 0.5929 - val_loss: 1.8121
# Epoch 88/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8828 - loss: 0.3234 - val_accuracy: 0.5905 - val_loss: 1.7537
# Epoch 89/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8777 - loss: 0.3331 - val_accuracy: 0.5867 - val_loss: 1.7513
# Epoch 90/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8796 - loss: 0.3303 - val_accuracy: 0.5840 - val_loss: 1.7983
# Epoch 91/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8756 - loss: 0.3469 - val_accuracy: 0.5883 - val_loss: 1.7695
# Epoch 92/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8778 - loss: 0.3409 - val_accuracy: 0.5896 - val_loss: 1.7929
# Epoch 93/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8778 - loss: 0.3440 - val_accuracy: 0.5929 - val_loss: 1.8162
# Epoch 94/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8777 - loss: 0.3387 - val_accuracy: 0.5916 - val_loss: 1.8659
# Epoch 95/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8951 - loss: 0.3004 - val_accuracy: 0.5766 - val_loss: 1.8077
# Epoch 96/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8856 - loss: 0.3136 - val_accuracy: 0.5838 - val_loss: 1.8086
# Epoch 97/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8820 - loss: 0.3345 - val_accuracy: 0.5859 - val_loss: 1.8394
# Epoch 98/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8800 - loss: 0.3243 - val_accuracy: 0.5813 - val_loss: 1.8932
# Epoch 99/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8902 - loss: 0.3170 - val_accuracy: 0.5810 - val_loss: 1.8939
# Epoch 100/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8882 - loss: 0.3154 - val_accuracy: 0.5865 - val_loss: 1.8762

# %%
# Plot of the training history

# Accuray 
plt.plot(history.history['accuracy'],'r')
plt.plot(history.history['val_accuracy'],'b')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Loss 
plt.plot(history.history['loss'],'r')
plt.plot(history.history['val_loss'],'b')

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Image augmentation

# %%
# Neural network parameters
#-----------------------------------------------
#-----------------------------------------------
batch_size = 64 # 
epochs = 100 # 
#-----------------------------------------------
#-----------------------------------------------
num_classes = 10
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols,3)

# Model
model = Sequential()
#-----------------------------------------------
#-----------------------------------------------
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=input_shape)) 
#-----------------------------------------------
#-----------------------------------------------
model.add(MaxPooling2D(pool_size=(2, 2)))
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(0.1)) # Value between 0 and 1 
#-----------------------------------------------
model.add(Conv2D(32, (3, 3), activation='relu')) 
#-----------------------------------------------
#-----------------------------------------------
model.add(MaxPooling2D(pool_size=(2, 2)))
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(0.1)) # Value between 0 and 1 
#-----------------------------------------------
#-----------------------------------------------
model.add(Flatten()) 
model.add(Dense(50, activation='relu')) 
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(0.1)) # Value between 0 and 1 
#-----------------------------------------------
#-----------------------------------------------
model.add(Dense(num_classes, activation='softmax'))


model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

#### Image augmentation ####

from tensorflow.keras.preprocessing.image import ImageDataGenerator
# construct the training image generator for data augmentation
aug = ImageDataGenerator(rotation_range=20, zoom_range=0.15,
width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
horizontal_flip=True, fill_mode="nearest")
 
# train the network
history_aug = model.fit(aug.flow(X_train, y_train, batch_size=batch_size),epochs=epochs,validation_data = (X_test,y_test))
# Out:
# Epoch 1/100
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.1488 - loss: 2.2182 - val_accuracy: 0.3345 - val_loss: 1.8833
# Epoch 2/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.2776 - loss: 1.9135 - val_accuracy: 0.3660 - val_loss: 1.7451
# Epoch 3/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.3193 - loss: 1.8257 - val_accuracy: 0.4203 - val_loss: 1.6447
# Epoch 4/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.3354 - loss: 1.7801 - val_accuracy: 0.4303 - val_loss: 1.5879
# Epoch 5/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.3612 - loss: 1.7254 - val_accuracy: 0.4518 - val_loss: 1.5063
# Epoch 6/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.3807 - loss: 1.6703 - val_accuracy: 0.4507 - val_loss: 1.4975
# Epoch 7/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.3967 - loss: 1.6316 - val_accuracy: 0.4588 - val_loss: 1.4885
# Epoch 8/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.3951 - loss: 1.6398 - val_accuracy: 0.4896 - val_loss: 1.4187
# Epoch 9/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.4209 - loss: 1.5841 - val_accuracy: 0.5004 - val_loss: 1.4060
# Epoch 10/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.4209 - loss: 1.5823 - val_accuracy: 0.4939 - val_loss: 1.3981
# Epoch 11/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.4258 - loss: 1.5570 - val_accuracy: 0.4969 - val_loss: 1.3933
# Epoch 12/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.4235 - loss: 1.5477 - val_accuracy: 0.4874 - val_loss: 1.4174
# Epoch 13/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.4454 - loss: 1.5198 - val_accuracy: 0.5118 - val_loss: 1.3438
# Epoch 14/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.4455 - loss: 1.5151 - val_accuracy: 0.5130 - val_loss: 1.3460
# Epoch 15/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.4509 - loss: 1.4947 - val_accuracy: 0.5024 - val_loss: 1.3812
# Epoch 16/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.4442 - loss: 1.5114 - val_accuracy: 0.4941 - val_loss: 1.3880
# Epoch 17/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.4538 - loss: 1.4995 - val_accuracy: 0.5343 - val_loss: 1.3028
# Epoch 18/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.4636 - loss: 1.4648 - val_accuracy: 0.5182 - val_loss: 1.3402
# Epoch 19/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.4699 - loss: 1.4775 - val_accuracy: 0.5100 - val_loss: 1.3674
# Epoch 20/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.4644 - loss: 1.4681 - val_accuracy: 0.5207 - val_loss: 1.3208
# Epoch 21/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.4745 - loss: 1.4558 - val_accuracy: 0.5287 - val_loss: 1.2867
# Epoch 22/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.4761 - loss: 1.4488 - val_accuracy: 0.5429 - val_loss: 1.2651
# Epoch 23/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.4754 - loss: 1.4281 - val_accuracy: 0.5351 - val_loss: 1.2726
# Epoch 24/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.4962 - loss: 1.3921 - val_accuracy: 0.5484 - val_loss: 1.2561
# Epoch 25/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.4846 - loss: 1.4240 - val_accuracy: 0.5200 - val_loss: 1.3504
# Epoch 26/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.4917 - loss: 1.4099 - val_accuracy: 0.5519 - val_loss: 1.2432
# Epoch 27/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.4939 - loss: 1.3967 - val_accuracy: 0.5516 - val_loss: 1.2403
# Epoch 28/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.4861 - loss: 1.4154 - val_accuracy: 0.5529 - val_loss: 1.2471
# Epoch 29/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5051 - loss: 1.3745 - val_accuracy: 0.5547 - val_loss: 1.2259
# Epoch 30/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5096 - loss: 1.3622 - val_accuracy: 0.5567 - val_loss: 1.2308
# Epoch 31/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5001 - loss: 1.3662 - val_accuracy: 0.5647 - val_loss: 1.2276
# Epoch 32/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.4953 - loss: 1.3897 - val_accuracy: 0.5693 - val_loss: 1.2097
# Epoch 33/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5099 - loss: 1.3528 - val_accuracy: 0.5729 - val_loss: 1.1980
# Epoch 34/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5000 - loss: 1.3711 - val_accuracy: 0.5448 - val_loss: 1.2659
# Epoch 35/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5148 - loss: 1.3344 - val_accuracy: 0.5886 - val_loss: 1.1521
# Epoch 36/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5086 - loss: 1.3544 - val_accuracy: 0.5680 - val_loss: 1.2247
# Epoch 37/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5135 - loss: 1.3581 - val_accuracy: 0.5600 - val_loss: 1.2190
# Epoch 38/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5105 - loss: 1.3586 - val_accuracy: 0.5655 - val_loss: 1.2171
# Epoch 39/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5220 - loss: 1.3272 - val_accuracy: 0.5812 - val_loss: 1.1701
# Epoch 40/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5124 - loss: 1.3422 - val_accuracy: 0.5610 - val_loss: 1.2138
# Epoch 41/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5229 - loss: 1.3433 - val_accuracy: 0.5818 - val_loss: 1.1759
# Epoch 42/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5316 - loss: 1.3280 - val_accuracy: 0.5750 - val_loss: 1.1676
# Epoch 43/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5208 - loss: 1.3288 - val_accuracy: 0.5575 - val_loss: 1.2362
# Epoch 44/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5244 - loss: 1.3377 - val_accuracy: 0.5814 - val_loss: 1.1796
# Epoch 45/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5317 - loss: 1.3025 - val_accuracy: 0.5880 - val_loss: 1.1565
# Epoch 46/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5376 - loss: 1.2996 - val_accuracy: 0.5930 - val_loss: 1.1394
# Epoch 47/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5247 - loss: 1.3221 - val_accuracy: 0.5911 - val_loss: 1.1330
# Epoch 48/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5195 - loss: 1.3218 - val_accuracy: 0.5730 - val_loss: 1.1860
# Epoch 49/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5311 - loss: 1.2984 - val_accuracy: 0.5914 - val_loss: 1.1442
# Epoch 50/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5331 - loss: 1.2987 - val_accuracy: 0.5855 - val_loss: 1.1632
# Epoch 51/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5342 - loss: 1.3097 - val_accuracy: 0.5926 - val_loss: 1.1285
# Epoch 52/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5397 - loss: 1.2860 - val_accuracy: 0.5897 - val_loss: 1.1434
# Epoch 53/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5340 - loss: 1.3063 - val_accuracy: 0.5755 - val_loss: 1.1944
# Epoch 54/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5241 - loss: 1.3083 - val_accuracy: 0.5971 - val_loss: 1.1193
# Epoch 55/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5371 - loss: 1.2908 - val_accuracy: 0.5908 - val_loss: 1.1461
# Epoch 56/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5367 - loss: 1.2747 - val_accuracy: 0.5891 - val_loss: 1.1453
# Epoch 57/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.5341 - loss: 1.2980 - val_accuracy: 0.5771 - val_loss: 1.1695
# Epoch 58/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5443 - loss: 1.2854 - val_accuracy: 0.5901 - val_loss: 1.1446
# Epoch 59/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.5365 - loss: 1.2712 - val_accuracy: 0.5962 - val_loss: 1.1378
# Epoch 60/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.5424 - loss: 1.2730 - val_accuracy: 0.6058 - val_loss: 1.1046
# Epoch 61/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5392 - loss: 1.2962 - val_accuracy: 0.5782 - val_loss: 1.1742
# Epoch 62/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5452 - loss: 1.2684 - val_accuracy: 0.5937 - val_loss: 1.1156
# Epoch 63/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5442 - loss: 1.2687 - val_accuracy: 0.5718 - val_loss: 1.1797
# Epoch 64/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5541 - loss: 1.2488 - val_accuracy: 0.5982 - val_loss: 1.1230
# Epoch 65/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5467 - loss: 1.2500 - val_accuracy: 0.6005 - val_loss: 1.1243
# Epoch 66/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5542 - loss: 1.2592 - val_accuracy: 0.6038 - val_loss: 1.1008
# Epoch 67/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5486 - loss: 1.2438 - val_accuracy: 0.6092 - val_loss: 1.0889
# Epoch 68/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5331 - loss: 1.2778 - val_accuracy: 0.5921 - val_loss: 1.1492
# Epoch 69/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.5620 - loss: 1.2450 - val_accuracy: 0.5923 - val_loss: 1.1332
# Epoch 70/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5424 - loss: 1.2643 - val_accuracy: 0.5882 - val_loss: 1.1602
# Epoch 71/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5530 - loss: 1.2527 - val_accuracy: 0.6108 - val_loss: 1.0961
# Epoch 72/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5513 - loss: 1.2528 - val_accuracy: 0.5922 - val_loss: 1.1192
# Epoch 73/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5507 - loss: 1.2453 - val_accuracy: 0.5940 - val_loss: 1.1289
# Epoch 74/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5515 - loss: 1.2513 - val_accuracy: 0.6047 - val_loss: 1.0970
# Epoch 75/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5489 - loss: 1.2340 - val_accuracy: 0.5882 - val_loss: 1.1621
# Epoch 76/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5532 - loss: 1.2410 - val_accuracy: 0.5923 - val_loss: 1.1355
# Epoch 77/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.5563 - loss: 1.2197 - val_accuracy: 0.6108 - val_loss: 1.0970
# Epoch 78/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5635 - loss: 1.2263 - val_accuracy: 0.5846 - val_loss: 1.1772
# Epoch 79/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5620 - loss: 1.2198 - val_accuracy: 0.5995 - val_loss: 1.1246
# Epoch 80/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5577 - loss: 1.2426 - val_accuracy: 0.5835 - val_loss: 1.1738
# Epoch 81/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5586 - loss: 1.2355 - val_accuracy: 0.5744 - val_loss: 1.2003
# Epoch 82/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5634 - loss: 1.2224 - val_accuracy: 0.6205 - val_loss: 1.0607
# Epoch 83/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.5630 - loss: 1.2082 - val_accuracy: 0.6082 - val_loss: 1.1117
# Epoch 84/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.5640 - loss: 1.2177 - val_accuracy: 0.6034 - val_loss: 1.1194
# Epoch 85/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5673 - loss: 1.2116 - val_accuracy: 0.5743 - val_loss: 1.1935
# Epoch 86/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5588 - loss: 1.2617 - val_accuracy: 0.6150 - val_loss: 1.0776
# Epoch 87/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.5582 - loss: 1.2290 - val_accuracy: 0.6159 - val_loss: 1.0805
# Epoch 88/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5509 - loss: 1.2207 - val_accuracy: 0.6054 - val_loss: 1.1048
# Epoch 89/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.5720 - loss: 1.2001 - val_accuracy: 0.6147 - val_loss: 1.0733
# Epoch 90/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.5634 - loss: 1.2089 - val_accuracy: 0.5943 - val_loss: 1.1357
# Epoch 91/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5723 - loss: 1.1924 - val_accuracy: 0.6177 - val_loss: 1.0801
# Epoch 92/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5637 - loss: 1.2283 - val_accuracy: 0.6052 - val_loss: 1.1133
# Epoch 93/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5672 - loss: 1.2030 - val_accuracy: 0.5966 - val_loss: 1.1417
# Epoch 94/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5702 - loss: 1.1988 - val_accuracy: 0.6316 - val_loss: 1.0526
# Epoch 95/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5702 - loss: 1.2187 - val_accuracy: 0.6125 - val_loss: 1.0915
# Epoch 96/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5644 - loss: 1.2232 - val_accuracy: 0.6100 - val_loss: 1.0941
# Epoch 97/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5693 - loss: 1.2077 - val_accuracy: 0.6105 - val_loss: 1.0859
# Epoch 98/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5774 - loss: 1.1885 - val_accuracy: 0.6095 - val_loss: 1.0941
# Epoch 99/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5638 - loss: 1.2253 - val_accuracy: 0.6161 - val_loss: 1.0847
# Epoch 100/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5767 - loss: 1.1914 - val_accuracy: 0.6233 - val_loss: 1.0511

# %%
# Plot of the training history

# Accuray 
plt.plot(history_aug.history['accuracy'],'r')
plt.plot(history_aug.history['val_accuracy'],'b')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Loss 
plt.plot(history_aug.history['loss'],'r')
plt.plot(history_aug.history['val_loss'],'b')

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Comparison CNNs with and without image augmentation

# Accuray 
plt.plot(history.history['val_accuracy'],'b')
plt.plot(history_aug.history['val_accuracy'],'r')
plt.title('Comparison accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['without augmentation', 'with augmentation'], loc='upper left')
plt.show()
